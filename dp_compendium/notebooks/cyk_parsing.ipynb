# %% [markdown]
# # CYK Parsing (CNF)
#
# Bottom-up DP to decide whether string s is generated by a CNF grammar.

# %%
from cyk_parsing import cyk_parse
prods={'S':[('S','S'),'A'], 'A':['a']}
cyk_parse({'a'}, prods, 'S', 'aa')
